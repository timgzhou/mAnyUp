# %%
# !ls
# Out:
# cache	     env_setup		pastis_visualize  sen12flood_sample.png
# checkpoints  exp		pyproject.toml	  src
# configs      features		README.md	  temp.ipynb
# data	     feature_viz	reference	  test.py
# docs	     feature_viz_sweep	requirements.txt  tests
# env	     LICENSE		results		  train.py
# env_olmo     logs		scripts		  Untitled.ipynb

# %%
from IPython.display import Image, display

# Provide the path to your PNG file
display(Image(filename='sen12flood_sample.png'))
